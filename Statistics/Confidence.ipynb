# %% [markdown]
# <img src="https://imgur.com/n8bpIdO.png" />

# %% [markdown]
# <img src="https://i.imgur.com/Hn1aILh.png" />

# %%
from scipy import stats

# %%
z = 1.96

# %%
max = 600 + 50*1.96/25**.5
max
# Out:
# 619.6

# %%
min = 600 - 50*1.96/25**.5
min
# Out:
# 580.4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
z = 1.96
p_x = 375/500
p_upper = p_x + z*((p_x*(1-p_x)/500)**.5)
p_lower = p_x - z*((p_x*(1-p_x)/500)**.5)

print(p_upper,p_lower)
# Out:
# 0.7879552367928326 0.7120447632071674

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data  = [3.8,4,4.2,4.2,4.5,4.8,5.4,5.8,6.2,6.8,7.2,8.5]

# %%
import pandas as pd

# %%
data = pd.Series(data)

# %%
data.std()
# Out:
# 1.4817066327227348

# %%
data.mean()
# Out:
# 5.45

# %%
z=.196

# %%
upper  = data.mean()  + 1.96*data.std()/len(data)**.5
upper
# Out:
# 6.288354448797275

# %%
lower  = data.mean()  - 1.96*data.std()/len(data)**.5
lower
# Out:
# 4.6116455512027255

# %%
print("族群平均在 95%信心水準下 :",upper,lower)
# Out:
# 族群平均在 95%信心水準下 : 6.288354448797275 4.6116455512027255
