# %% [markdown]
# # 中央極限定理的說明
# * https://molecular-service-science.com/2013/07/27/central-limit-theorem-and-rule-of-thumb/
#
# 為了驗證中央極限定理是否有其特性，以下 mock 兩種分佈的 data 來作實驗

# %%
from numpy import random as npr
from random import sample
import numpy as np
np.random.seed =1
x = npr.random_integers(10,size=1000)
x = np.array(range(1000))
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning: This function is deprecated. Please call randint(1, 10 + 1) instead
#   """

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %% [markdown]
# # 這是一個 uniform distribution

# %%
plt.hist(x)
plt.title("Freq Dist")
plt.ylabel("Freq")
plt.xlabel("Value")
# Out:
# Text(0.5,0,'Value')

# %%
y=npr.normal(size=10000)
y
# Out:
# array([-1.6568065 , -0.34091263, -0.2091654 , ..., -2.12067788,
#         0.41209859, -0.06939357])

# %% [markdown]
# # 這是一個 Random 且是 Normal Distribution

# %%
plt.hist(y)
plt.title("Freq Dist")
plt.ylabel("Freq")
plt.xlabel("Value")
# Out:
# Text(0.5,0,'Value')

# %% [markdown]
# # 進行抽樣來驗證中央極限定理

# %% [markdown]
# ## 實驗一 : 對 x 為 uniform distribution ，每次抽兩筆

# %%
mean_list = []
for _ in range(10):
    m = np.mean(sample(list(x),2))
    mean_list.append(m)
plt.hist(mean_list)
plt.title("Freq Dist")
plt.ylabel("Freq")
plt.xlabel("Value")
# Out:
# Text(0.5,0,'Value')

# %%
# 進行抽樣 100 次
mean_list = []
for _ in range(100):
    m = np.mean(sample(list(x),2))
    mean_list.append(m)
plt.hist(mean_list)
plt.title("Freq Dist")
plt.ylabel("Freq")
plt.xlabel("Value")
# Out:
# Text(0.5,0,'Value')

# %%
# 進行抽樣 100 次
mean_list = []
for _ in range(1000):
    m = np.mean(sample(list(x),2))
    mean_list.append(m)
plt.hist(mean_list)
plt.title("Freq Dist")
plt.ylabel("Freq")
plt.xlabel("Value")
# Out:
# Text(0.5,0,'Value')

# %% [markdown]
# ## 實驗二 : 對 x 為 uniform distribution ，每次抽30筆

# %%
mean_list = []
for _ in range(10):
    m = np.mean(sample(list(x),30))
    mean_list.append(m)
plt.hist(mean_list)
plt.title("Freq Dist")
plt.ylabel("Freq")
plt.xlabel("Value")
# Out:
# Text(0.5,0,'Value')

# %%
mean_list = []
for _ in range(100):
    m = np.mean(sample(list(x),30))
    mean_list.append(m)
plt.hist(mean_list)
plt.title("Freq Dist")
plt.ylabel("Freq")
plt.xlabel("Value")
# Out:
# Text(0.5,0,'Value')

# %%
mean_list = []
for _ in range(1000):
    m = np.mean(sample(list(x),30))
    mean_list.append(m)
plt.hist(mean_list)
plt.title("Freq Dist")
plt.ylabel("Freq")
plt.xlabel("Value")
# Out:
# Text(0.5,0,'Value')

# %% [markdown]
# ## 實驗三 : 對 x 為 normal distribution ，每次抽2筆

# %%
mean_list = []
for _ in range(10):
    m = np.mean(sample(list(y),2))
    mean_list.append(m)
plt.hist(mean_list)
plt.title("Freq Dist")
plt.ylabel("Freq")
plt.xlabel("Value")
# Out:
# Text(0.5,0,'Value')

# %%
mean_list = []
for _ in range(100):
    m = np.mean(sample(list(y),2))
    mean_list.append(m)
plt.hist(mean_list)
plt.title("Freq Dist")
plt.ylabel("Freq")
plt.xlabel("Value")
# Out:
# Text(0.5,0,'Value')

# %%
mean_list = []
for _ in range(1000):
    m = np.mean(sample(list(y),2))
    mean_list.append(m)
plt.hist(mean_list)
plt.title("Freq Dist")
plt.ylabel("Freq")
plt.xlabel("Value")
# Out:
# Text(0.5,0,'Value')

# %% [markdown]
# ## 實驗四 : 對 x 為 normal distribution ，每次抽30筆

# %%
mean_list = []
for _ in range(10):
    m = np.mean(sample(list(y),30))
    mean_list.append(m)
plt.hist(mean_list)
plt.title("Freq Dist")
plt.ylabel("Freq")
plt.xlabel("Value")
# Out:
# Text(0.5,0,'Value')

# %%
mean_list = []
for _ in range(100):
    m = np.mean(sample(list(y),30))
    mean_list.append(m)
plt.hist(mean_list)
plt.title("Freq Dist")
plt.ylabel("Freq")
plt.xlabel("Value")
# Out:
# Text(0.5,0,'Value')

# %%
mean_list = []
for _ in range(1000):
    m = np.mean(sample(list(y),30))
    mean_list.append(m)
plt.hist(mean_list)
plt.title("Freq Dist")
plt.ylabel("Freq")
plt.xlabel("Value")
# Out:
# Text(0.5,0,'Value')

# %% [markdown]
# # 結論:
# * 抽越多次其平均數的分佈會越接近常態分佈
# * 不論其它原始的分佈為何
