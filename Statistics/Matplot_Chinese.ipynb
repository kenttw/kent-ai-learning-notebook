# %% [markdown]
# # 第一步先確定你的 Matplot 的設定檔的位置

# %%
import matplotlib
print(matplotlib.matplotlib_fname())
# Out:
# /Users/kent/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/matplotlibrc

# %% [markdown]
# # 修改 Matplot 設定檔 (註:因為是系統檔請使用 admin 權限來修變)
# * ```sudo vim /usr/local/lib/python3.6/site-packages/matplotlib/mpl-data/matplotlibrc```
# * 找到兩行，把註解拿到，並加上 "SimHei"
# ```
# #font.serif
# #font.sans-serif
# ```
# *
# ![image.png](https://i.imgur.com/yI6LFkd.png)
#
# * 最後記得存檔喔!!!

# %% [markdown]
# # 先清空 Matplot 的 Cache File
# * ``` rm -rvf  ~/.matplotlib```

# %% [markdown]
# # 確認自已的 Python Library 的位置

# %%
import sys
print('\n'.join(sys.path))
# Out:
# /Users/kent/git/aiacademy-learning-notebook/Statistics
# /Users/kent/anaconda3/lib/python37.zip
# /Users/kent/anaconda3/lib/python3.7
# /Users/kent/anaconda3/lib/python3.7/lib-dynload
#
# /Users/kent/.local/lib/python3.7/site-packages
# /Users/kent/anaconda3/lib/python3.7/site-packages
# /Users/kent/anaconda3/lib/python3.7/site-packages/aeosa
# /Users/kent/git/tag2url/src/slack-cleaner
# /Users/kent/anaconda3/lib/python3.7/site-packages/IPython/extensions
# /Users/kent/.ipython

# %% [markdown]
# # 自已到 Google 上面去找細明體
# * [按我然後自已下載吧！！](https://www.google.com.tw/search?q=simhei+%E7%B9%81%E9%AB%94+download&oq=simhei+%E7%B9%81%E9%AB%94+download&)

# %% [markdown]
# # 然後將字體檔 Copy 到 Python Library Font Folder 裡面
# * ```cd {你的python library} /matplotlib/mpl-data/fonts/ttf``` 例如以下
# * ```cd /usr/local/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf```
# * ```sudo cp ~/Desktop/simheittf/simhei.ttf ./```

# %%
# %pylab inline
x = linspace(-5, 5, 2000)
plot(x, sinc(x))
plt.gcf().set_size_inches(20, 8)
plt.title(u'sinc(x)圖形', )
plt.xlabel(u'-5到5範圍', )
plt.ylabel(u'sinc(x)', )
plt.tick_params(axis ='both', labelsize=10)
plt.savefig('sample.png')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/kent/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kent/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import matplotlib
fm = matplotlib.font_manager.FontManager()
for f in fm.ttflist:
    print(f.name)
# Out:
# STIXNonUnicode
# DejaVu Sans Mono
# cmr10
# cmsy10
# DejaVu Sans Mono
# STIXGeneral
# STIXSizeThreeSym
# cmb10
# STIXSizeOneSym
# STIXSizeFourSym
# STIXGeneral
# DejaVu Serif
# STIXGeneral
# STIXGeneral
# STIXSizeTwoSym
# DejaVu Sans Display
# STIXSizeOneSym
# STIXNonUnicode
# SimHei
# DejaVu Serif
# cmex10
# STIXNonUnicode
# DejaVu Serif
# STIXSizeTwoSym
# cmtt10
# STIXNonUnicode
# DejaVu Sans Mono
# DejaVu Sans
# DejaVu Serif Display
# DejaVu Sans
# DejaVu Serif
# cmmi10
# STIXSizeFourSym
# STIXSizeFiveSym
# DejaVu Sans Mono
# STIXSizeThreeSym
# cmss10
# DejaVu Sans
# DejaVu Sans
# .Helvetica Neue DeskInterface
# STIXGeneral
# Bitstream Vera Sans
# Arial Rounded MT Bold
# Serto Batnan
# Bitstream Vera Sans Mono
# Georgia
# Georgia
# SignPainter
# Apple Braille
# Sana
# .SF NS Display Condensed
# Luxi Sans
# Kohinoor Telugu
# Luxi Serif
# NovaMono for Powerline
# Plantagenet Cherokee
# Luxi Serif
# Noteworthy
# Meslo LG S for Powerline
# Khmer Sangam MN
# Bitstream Vera Serif
# ...

# %%
# %pylab inline
import pandas as pd
from matplotlib import font_manager
fig = pd.DataFrame([1,2,3],columns=['我是中文'])
plot(fig)
# Note the next lines
plt.legend(loc=0, )
plt.title('歡迎來使用痞客邦服務', )

plt.grid(True)
plt.axis('tight')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/kent/anaconda3/lib/python3.7/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# No handles with labels found to put in legend.
# (-0.1, 2.1, 0.9, 3.1)

# %%
fig.plot()

# %% [markdown]
# # Seaborn 的設定方法

# %%
# %config InlineBackend.figure_format='svg'
#config InlineBackend.figure_format='retina'


import seaborn as sns
sns.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=False, rc=None)
sns.set_style("darkgrid",{"font.sans-serif":['simhei','Droid Sans Fallback']})
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset("tips")
sns.boxplot(x=tips["total_bill"]).set_title("我是中文")

plt.show()
