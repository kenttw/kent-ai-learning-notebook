# %% [markdown]
# # [Reference](https://machinelearningmastery.com/what-is-imbalanced-classification/)
# * ROC Curve: 假設全國有 100 小偷及 1000 位，如今我們實作了犯罪偵測器，我們使用用 ROC Curve 來衡量。
#  * True Positvie Rate : 有多少比率 罪犯 positive example 被你正確偵測到。
#  * False Positive Rate : 有多少比率 全國良民被誤認為罪犯。
#  * 故有兩種以下極端
#   * 全部都不抓，及是左下角的狀況
#   * 全部都抓(判有罪)及是右上角的狀況
# * ![image.png](attachment:image.png)
# * F-Beta Score
#  * if beta is zeor that favor recall , if beta is very large , we favor precision.
# ![image-2.png](attachment:image-2.png )
