# %%
from slacker import Slacker
slack = Slacker('xoxb-159140174545-BVgSsIT2YMpqt41NNbbHVXHg')
def slack_log(message):
    try:
        slack.chat.post_message('#log-gpu', "GPUtil:   {}".format(message))
    except:
        print("slack connection error")

slack_log('Initial Logger')

# %%
from time import sleep
import GPUtil as GPU
gpus = GPU.getGPUs()

while True:
    for gpu in gpus:

        m = gpu.memoryUtil
        l = gpu.load
        name = gpu.name

        ds = "GPU:%s Load:%1.2f  Memory:%1.2f "%(name,l,m)

        print(ds)
        slack_log(ds)
    sleep(60)
# Out:
# GPU:Tesla K80 Load:0.46  Memory:0.95
# GPU:Tesla K80 Load:0.00  Memory:0.95
# GPU:Tesla K80 Load:0.46  Memory:0.95
# GPU:Tesla K80 Load:0.00  Memory:0.95
# GPU:Tesla K80 Load:0.46  Memory:0.95
# GPU:Tesla K80 Load:0.00  Memory:0.95
# GPU:Tesla K80 Load:0.46  Memory:0.95
# GPU:Tesla K80 Load:0.00  Memory:0.95
# GPU:Tesla K80 Load:0.46  Memory:0.95
# GPU:Tesla K80 Load:0.00  Memory:0.95
# GPU:Tesla K80 Load:0.46  Memory:0.95
# GPU:Tesla K80 Load:0.00  Memory:0.95
# GPU:Tesla K80 Load:0.46  Memory:0.95
# GPU:Tesla K80 Load:0.00  Memory:0.95
# GPU:Tesla K80 Load:0.46  Memory:0.95
# GPU:Tesla K80 Load:0.00  Memory:0.95
# GPU:Tesla K80 Load:0.46  Memory:0.95
# GPU:Tesla K80 Load:0.00  Memory:0.95
# GPU:Tesla K80 Load:0.46  Memory:0.95
# GPU:Tesla K80 Load:0.00  Memory:0.95
# GPU:Tesla K80 Load:0.46  Memory:0.95
# GPU:Tesla K80 Load:0.00  Memory:0.95
# GPU:Tesla K80 Load:0.46  Memory:0.95
# GPU:Tesla K80 Load:0.00  Memory:0.95
# GPU:Tesla K80 Load:0.46  Memory:0.95
# ...
