# %%
import pandas as pd
from sklearn import metrics

# %%
train = pd.read_csv("./train.csv", header=None,)

# %%
train.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.299403 -1.226624  1.498425 -1.176150  5.289853  0.208297  2.404498
# 1 -1.174176  0.332157  0.949919 -1.285328  2.199061 -0.151268 -0.427039
# 2  1.192222 -0.414371  0.067054 -2.233568  3.658881  0.089007  0.203439
# 3  1.573270 -0.580318 -0.866332 -0.603812  3.125716  0.870321 -0.161992
# 4 -0.613071 -0.644204  1.112558 -0.032397  3.490142 -0.011935  1.443521
#
#          7         8         9     ...           30        31        32  \
# 0  1.594506 -0.051608  0.663234    ...    -0.850465 -0.622990 -1.833057
# 1  2.619246 -0.765884 -0.093780    ...    -0.819750  0.012037  2.038836
# 2 -4.219054 -1.184919 -1.240310    ...    -0.604501  0.750054 -3.360521
# 3  4.499666  1.038741 -1.092716    ...     1.022959  1.275598 -3.480110
# 4 -4.290282 -1.761308  0.807652    ...     0.513906 -1.803473  0.518579
#
#          33        34        35        36        37        38        39
# ...

# %%
train.describe()
# Out:
#                 0            1            2            3            4   \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.025596    -0.024526    -0.024088    -0.002271     1.092329
# std       1.008282     1.016298     0.979109     0.970575     4.538834
# min      -3.365711    -3.492086    -2.695602    -3.460471   -16.421901
# 25%      -0.669010    -0.693937    -0.698830    -0.617557    -1.801997
# 50%       0.027895    -0.033194     0.008145     0.002327     0.862818
# 75%       0.762520     0.682753     0.661434     0.640743     3.843172
# max       3.326246     3.583870     2.546507     3.088738    17.565345
#
#                 5            6            7            8            9   \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     -0.006250     0.497342    -0.037883     0.026391    -0.003597
# std       0.989128     2.118819     2.232256     1.001064     1.013520
# ...

# %%
lablel = pd.read_csv("./trainLabels.csv", header=None,)
lablel.describe()
# Out:
#                 0
# count  1000.00000
# mean      0.51000
# std       0.50015
# min       0.00000
# 25%       0.00000
# 50%       1.00000
# 75%       1.00000
# max       1.00000

# %%
X = train.values

# %%
Y = lablel.values

# %%
from sklearn import preprocessing

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.25, random_state=1)

# %% [markdown]
# # Do Normalization

# %%
from sklearn.preprocessing import StandardScaler
stds = StandardScaler()
X_train_scaled = stds.fit_transform(X_train)
X_test_scaled = stds.transform(X_test)

# %% [markdown]
# # Dimession Reduction

# %%
from sklearn import decomposition
pca = decomposition.PCA(n_components=40,whiten=True)
X_train_pca = pca.fit_transform(X_train_scaled)

# %%
X_test_pca = pca.transform(X_test_scaled)

# %%
plt.plot(pca.explained_variance_ratio_)

# %%
plt.plot(X_train_pca[:,0])

# %%
plt.plot(X_train_pca[:,10])

# %%
plt.plot(X_train_pca[:,39])

# %%
def qq_plot(x):
    from scipy.stats import probplot
    probplot(x, dist='norm', plot=plt)
    
qq_plot(X_train_pca[:,36])

# %%
from sklearn.linear_model import LogisticRegression
clf_l2_LR = LogisticRegression(penalty='l1', dual=False, tol=0.001, C=10, 
                               fit_intercept=True, intercept_scaling=1, class_weight=None, random_state=None, 
                               solver='liblinear', max_iter=1000, multi_class='ovr', verbose=0, 
                               warm_start=False, n_jobs=1)
from sklearn import svm
# X = [[0, 0], [1, 1]]
# y = [0, 1]
# clf = svm.SVC()

clf_l2_LR = svm.SVC(C=1.5, kernel='rbf', degree=1, gamma='auto', coef0=0.0, shrinking=True, probability=False, 
                    tol=0.001, cache_size=200, class_weight=None, verbose=False, max_iter=-1, 
                    decision_function_shape='ovr', random_state=None)



clf_l2_LR.fit(X_train_scaled,y_train)
predict_y = clf_l2_LR.predict(X_test_scaled)
print("accuracy_score",metrics.accuracy_score(y_test,predict_y))
print("f1_score",metrics.f1_score(y_test,predict_y,average='micro'))

print("recall_score",metrics.recall_score(y_test,predict_y,average='micro'))
print("precision_score",metrics.precision_score(y_test,predict_y,average='micro'))
# Out:
# accuracy_score 0.884
# f1_score 0.884
# recall_score 0.884
# precision_score 0.884
# /usr/local/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# # Build a Final Classifier

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
stds_final = StandardScaler()
X_train = stds_final.fit_transform(X)


from sklearn import decomposition
pca = decomposition.PCA(n_components=40,whiten=True)
X_train = pca.fit_transform(X_train)

# %%
from sklearn.linear_model import LogisticRegression
# clf_l2_LR = LogisticRegression(penalty='l2', dual=False, tol=0.0001, C=0.1, 
#                                fit_intercept=True, intercept_scaling=1, class_weight=None, random_state=None, 
#                                solver='liblinear', max_iter=100, multi_class='ovr', verbose=0, 
#                                warm_start=False, n_jobs=1)

clf_l2_LR = svm.SVC(C=1.5, kernel='rbf', degree=1, gamma='auto', coef0=0.0, shrinking=True, probability=False, 
                    tol=0.001, cache_size=200, class_weight=None, verbose=False, max_iter=-1, 
                    decision_function_shape='ovr', random_state=None)

clf_l2_LR.fit(X_train,Y)
predict_y = clf_l2_LR.predict(X_train)
print("accuracy_score",metrics.accuracy_score(Y,predict_y))
print("f1_score",metrics.f1_score(Y,predict_y,average='micro'))
# Out:
# accuracy_score 0.976
# f1_score 0.976
# /usr/local/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# # Do Prediction

# %%
test = pd.read_csv("./test.csv", header=None,)
test.describe()
# Out:
#                 0            1            2            3            4   \
# count  9000.000000  9000.000000  9000.000000  9000.000000  9000.000000
# mean      0.011814     0.004261    -0.001708     0.008614     1.262429
# std       1.009514     1.011432     0.996685     0.989010     4.527492
# min      -3.568633    -4.238067    -3.587473    -3.646144   -17.296514
# 25%      -0.669886    -0.678792    -0.665240    -0.662560    -1.669099
# 50%       0.006104     0.010758     0.007384     0.009027     1.123982
# 75%       0.703350     0.684755     0.658111     0.683506     4.002391
# max       3.843549     3.538868     3.716102     3.667817    20.551947
#
#                 5            6            7            8            9   \
# count  9000.000000  9000.000000  9000.000000  9000.000000  9000.000000
# mean      0.006003     0.480585    -0.017228     0.006883    -0.006664
# std       0.999623     2.102394     2.204673     0.989207     0.991570
# ...

# %%
test_scaled = stds_final.transform(test)

test_scaled = pca.fit_transform(test_scaled)

# %%
test_result = clf_l2_LR.predict(test_scaled)

# %%
test_result_pd = pd.DataFrame(test_result,columns=['Solution'])
test_result_pd.index += 1

# %%
test_result_pd.describe()
# Out:
#           Solution
# count  9000.000000
# mean      0.537111
# std       0.498649
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %%
test_result_pd.to_csv("./predict_result.csv",index=True,index_label='Id')
