# %% [markdown]
# # Basic Information
# * title: "Deduplication of contact information"
# * author: "Kent Shih"
# * date: "14 10, 2019"

# %% [markdown]
# # Data exploration
# * Some missing value
# * ??_equality is same as ??, so we remove those columns
# * the number of postive data and negatvie data are both balance
# * the values of columns have been standarization ?
# * the number of data is sufficent to build a hight complexity model such as deep learning

# %%
EVA_SIZE = 2500

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold, train_test_split, GridSearchCV

# %%
# read from row data and do suffle 
data_df = pd.read_csv("./address_matching_data.csv").sample(frac=1,random_state=1)
data_df[-10:]
# Out:
#               id  name_levenshtein_simple  name_trigram_simple  \
# 20609  2465#2478                 1.000000             1.000000
# 144      702#703                 0.545455             0.545455
# 21440  2097#2064                 1.000000             1.000000
# 19279  8258#8263                 0.080808             0.011111
# 7813   6549#6550                 0.222857             0.000000
# 10955  2177#2183                 1.000000             1.000000
# 17289  2260#2257                 0.977273             0.910714
# 5192   1177#1184                 0.693452             0.566667
# 12172    137#138                 1.000000             1.000000
# 235    8175#8181                 0.183838             0.033333
#
#        name_levenshtein_term  name_trigram_term city_levenshtein_simple  \
# 20609               1.000000           1.000000                0.666667
# 144                 0.377778           0.409091                       ?
# 21440               1.000000           1.000000                       ?
# 19279               0.088235           0.021739                       ?
# 7813                0.153846           0.000000                       1
# 10955               1.000000           1.000000                       1
# 17289               0.954545           0.800000                       ?
# 5192                0.695652           0.592593                       ?
# 12172               1.000000           1.000000                       ?
# 235                 0.117647           0.030303                       ?
#
#       city_trigram_simple city_levenshtein_term city_trigram_term  \
# 20609            0.666667              0.454545               0.5
# 144                     ?                     ?                 ?
# 21440                   ?                     ?                 ?
# 19279                   ?                     ?                 ?
# 7813                    1                     1                 1
# 10955                   1                     1                 1
# 17289                   ?                     ?                 ?
# 5192                    ?                     ?                 ?
# 12172                   ?                     ?                 ?
# 235                     ?                     ?                 ?
#
#       zip_levenshtein_simple  ... phone_levenshtein phone_trigram  \
# 20609                      1  ...                 ?             ?
# 144                        ?  ...                 ?             ?
# 21440                      ?  ...               1.0           1.0
# 19279                      ?  ...                 ?             ?
# 7813                       ?  ...               1.0           1.0
# 10955                      ?  ...               1.0           1.0
# 17289                      ?  ...               1.0           1.0
# 5192                       ?  ...                 ?             ?
# 12172                      ?  ...               1.0           1.0
# 235                        ?  ...                 ?             ?
#
#       fax_levenshtein fax_trigram street_number_levenshtein  \
# 20609               ?           ?                       1.0
# 144                 ?           ?                       1.0
# 21440               ?           ?                      0.75
# 19279               ?           ?                         ?
# 7813                ?           ?                         ?
# 10955               ?           ?                       1.0
# 17289               ?           ?                       1.0
# 5192                ?           ?                       1.0
# 12172               ?           ?                       0.5
# 235                 ?           ?                       0.5
#
#       street_number_trigram phone_equality fax_equality  \
# 20609                   1.0              m            m
# 144                     1.0              m            m
# 21440        0.428571432829              s            m
# 19279                     ?              m            m
# 7813                      ?              s            m
# 10955                   1.0              s            m
# 17289                   1.0              s            m
# 5192                    1.0              m            m
# 12172        0.285714298487              s            m
# 235                    0.25              m            m
#
#       street_number_equality is_match
# 20609                      s        1
# 144                        s        1
# 21440                      n        1
# 19279                      n       -1
# 7813                       n        1
# 10955                      s        1
# 17289                      s        1
# 5192                       s        1
# 12172                      n        1
# 235                        n       -1
#
# [10 rows x 31 columns]

# %%
test_df = pd.read_csv("./address_matching_test.csv")
test_df.head()
# Out:
#             id  name_levenshtein_simple  name_trigram_simple  \
# 0    7221#7218                 0.703704             0.666667
# 1    2393#2398                 1.000000             1.000000
# 2    2509#2510                 1.000000             1.000000
# 3    3695#3700                 0.111310             0.000000
# 4  15918#15955                 0.175000             0.074074
#
#    name_levenshtein_term  name_trigram_term city_levenshtein_simple  \
# 0               0.680000           0.533333                       1
# 1               0.520000           1.000000                0.666667
# 2               1.000000           1.000000                       ?
# 3               0.095238           0.000000                       1
# 4               0.153846           0.095238                       1
#
#   city_trigram_simple city_levenshtein_term city_trigram_term  \
# 0                   1                     1                 1
# 1            0.666667              0.454545               0.5
# 2                   ?                     ?                 ?
# 3                   1                     1                 1
# 4                   1                     1                 1
#
#   zip_levenshtein_simple  ... website_trigram_term phone_levenshtein  \
# 0                      1  ...                    ?               1.0
# 1                      1  ...                    ?                 ?
# 2                      ?  ...                    ?               1.0
# 3                    0.8  ...                    ?                 ?
# 4                      1  ...                    ?                 ?
#
#   phone_trigram fax_levenshtein fax_trigram street_number_levenshtein  \
# 0           1.0               ?           ?                       1.0
# 1             ?               ?           ?                       1.0
# 2           1.0               ?           ?                         ?
# 3             ?               ?           ?                         ?
# 4             ?               ?           ?                         ?
#
#   street_number_trigram phone_equality fax_equality street_number_equality
# 0                   1.0              s            m                      s
# 1                   1.0              m            m                      s
# 2                     ?              s            m                      n
# 3                     ?              m            m                      n
# 4                     ?              m            m                      n
#
# [5 rows x 30 columns]

# %%
# 超過一半是 Match 的
data_df.describe()
# Out:
#        name_levenshtein_simple  name_trigram_simple  name_levenshtein_term  \
# count             28235.000000         28235.000000           28235.000000
# mean                  0.628171             0.563277               0.537006
# std                   0.304767             0.369004               0.324820
# min                   0.000000             0.000000               0.000000
# 25%                   0.363387             0.222222               0.243243
# 50%                   0.666667             0.666667               0.476190
# 75%                   1.000000             1.000000               0.875000
# max                   1.000000             1.000000               1.000000
#
#        name_trigram_term     is_match
# count       28235.000000  28235.00000
# mean            0.509530      0.43524
# std             0.372265      0.90033
# min             0.000000     -1.00000
# 25%             0.142857     -1.00000
# 50%             0.483871      1.00000
# 75%             1.000000      1.00000
# max             1.000000      1.00000

# %%
# miss value rate
for c in data_df.columns:
    print(c,str(sum(data_df[c]=='?')/28235)[:4])
# Out:
# id 0.0
# name_levenshtein_simple 0.0
# name_trigram_simple 0.0
# name_levenshtein_term 0.0
# name_trigram_term 0.0
# city_levenshtein_simple 0.64
# city_trigram_simple 0.64
# city_levenshtein_term 0.64
# city_trigram_term 0.64
# zip_levenshtein_simple 0.72
# zip_trigram_simple 0.72
# zip_levenshtein_term 0.72
# zip_trigram_term 0.72
# street_levenshtein_simple 0.70
# street_trigram_simple 0.70
# street_levenshtein_term 0.70
# street_trigram_term 0.70
# website_levenshtein_simple 0.93
# website_trigram_simple 0.93
# website_levenshtein_term 0.93
# website_trigram_term 0.93
# phone_levenshtein 0.57
# phone_trigram 0.57
# fax_levenshtein 0.97
# fax_trigram 0.97
# street_number_levenshtein 0.34
# street_number_trigram 0.34
# phone_equality 0.0
# fax_equality 0.0
# street_number_equality 0.0
# is_match 0.0
# /usr/local/lib/python3.7/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
for c in data_df.columns:
    if 'equality' in c : 
        print("del",c)
        del data_df[c]
# Out:
# del phone_equality
# del fax_equality
# del street_number_equality

# %%
new_data_df = data_df.replace("?",-1)

for c in new_data_df.columns:
    print(c,str(sum(new_data_df[c]=='?')/28235)[:4])
# Out:
# id 0.0
# name_levenshtein_simple 0.0
# name_trigram_simple 0.0
# name_levenshtein_term 0.0
# name_trigram_term 0.0
# city_levenshtein_simple 0.0
# city_trigram_simple 0.0
# city_levenshtein_term 0.0
# city_trigram_term 0.0
# zip_levenshtein_simple 0.0
# zip_trigram_simple 0.0
# zip_levenshtein_term 0.0
# zip_trigram_term 0.0
# street_levenshtein_simple 0.0
# street_trigram_simple 0.0
# street_levenshtein_term 0.0
# street_trigram_term 0.0
# website_levenshtein_simple 0.0
# website_trigram_simple 0.0
# website_levenshtein_term 0.0
# website_trigram_term 0.0
# phone_levenshtein 0.0
# phone_trigram 0.0
# fax_levenshtein 0.0
# fax_trigram 0.0
# street_number_levenshtein 0.0
# street_number_trigram 0.0
# is_match 0.0

# %% [markdown]
# # Modeling approach
# * becasue we have a lot of labeled data so we could try to use a heavy model , such as deep learning
# * nn's performance is pretty good but i want to try another ml algorithn : lighGBN

# %%
import lightgbm as lgb
import keras

# %%
id_list = new_data_df['id'].tolist()
del new_data_df['id']
match_list = new_data_df['is_match'].tolist()
del new_data_df['is_match']

# %%
new_match_list = []
for v in  match_list:
    if v == 1 : new_match_list.append(1)
    else: new_match_list.append(0)

# %%
raw_data = new_data_df

# %%
raw_data
# Out:
#        name_levenshtein_simple  name_trigram_simple  name_levenshtein_term  \
# 18087                 1.000000             1.000000               1.000000
# 20865                 0.428571             0.036364               0.350000
# 5436                  1.000000             1.000000               1.000000
# 12287                 0.166667             0.083333               0.181818
# 1633                  0.857143             0.857143               0.304348
# ...                        ...                  ...                    ...
# 10955                 1.000000             1.000000               1.000000
# 17289                 0.977273             0.910714               0.954545
# 5192                  0.693452             0.566667               0.695652
# 12172                 1.000000             1.000000               1.000000
# 235                   0.183838             0.033333               0.117647
#
#        name_trigram_term city_levenshtein_simple city_trigram_simple  \
# 18087           1.000000                      -1                  -1
# 20865           0.028571                    0.25                   0
# 5436            1.000000                       1                   1
# 12287           0.066667                      -1                  -1
# 1633            0.695652                      -1                  -1
# ...                  ...                     ...                 ...
# 10955           1.000000                       1                   1
# 17289           0.800000                      -1                  -1
# 5192            0.592593                      -1                  -1
# 12172           1.000000                      -1                  -1
# 235             0.030303                      -1                  -1
#
#       city_levenshtein_term city_trigram_term zip_levenshtein_simple  \
# 18087                    -1                -1                     -1
# 20865              0.272727                 0                      0
# 5436                      1                 1                     -1
# 12287                    -1                -1                     -1
# 1633                     -1                -1                     -1
# ...                     ...               ...                    ...
# 10955                     1                 1                     -1
# 17289                    -1                -1                     -1
# 5192                     -1                -1                     -1
# 12172                    -1                -1                     -1
# 235                      -1                -1                     -1
#
#       zip_trigram_simple  ... website_levenshtein_simple  \
# 18087                 -1  ...                         -1
# 20865                  0  ...                         -1
# 5436                  -1  ...                         -1
# 12287                 -1  ...                         -1
# 1633                  -1  ...                         -1
# ...                  ...  ...                        ...
# 10955                 -1  ...                         -1
# 17289                 -1  ...                         -1
# 5192                  -1  ...                         -1
# 12172                 -1  ...                         -1
# 235                   -1  ...                         -1
#
#       website_trigram_simple website_levenshtein_term website_trigram_term  \
# 18087                     -1                       -1                   -1
# 20865                     -1                       -1                   -1
# 5436                      -1                       -1                   -1
# 12287                     -1                       -1                   -1
# 1633                      -1                       -1                   -1
# ...                      ...                      ...                  ...
# 10955                     -1                       -1                   -1
# 17289                     -1                       -1                   -1
# 5192                      -1                       -1                   -1
# 12172                     -1                       -1                   -1
# 235                       -1                       -1                   -1
#
#       phone_levenshtein   phone_trigram fax_levenshtein     fax_trigram  \
# 18087               1.0             1.0              -1              -1
# 20865               0.4  0.047619048506             0.3  0.047619048506
# 5436                 -1              -1              -1              -1
# 12287               1.0             1.0             1.0             1.0
# 1633                 -1              -1              -1              -1
# ...                 ...             ...             ...             ...
# 10955               1.0             1.0              -1              -1
# 17289               1.0             1.0              -1              -1
# 5192                 -1              -1              -1              -1
# 12172               1.0             1.0              -1              -1
# 235                  -1              -1              -1              -1
#
#       street_number_levenshtein street_number_trigram
# 18087                       1.0                   1.0
# 20865                        -1                    -1
# 5436                         -1                    -1
# 12287                        -1                    -1
# 1633                        1.0                   1.0
# ...                         ...                   ...
# 10955                       1.0                   1.0
# 17289                       1.0                   1.0
# 5192                        1.0                   1.0
# 12172                       0.5        0.285714298487
# 235                         0.5                  0.25
#
# [28235 rows x 26 columns]

# %% [markdown]
# ## data preparation

# %% [markdown]
# ## create lightGBM Dataset

# %%
y_train=new_match_list[:-EVA_SIZE]

# %%
X_train = raw_data[:-EVA_SIZE]

# %%
X_train = X_train.astype(float)

# %%
y_test = new_match_list[-EVA_SIZE:]
X_test = raw_data[-EVA_SIZE:]

# %%
X_test = X_test.astype(float)

# %%
gbm = lgb.LGBMClassifier(
    boosting_type='gbdt',
    num_leaves=31,
    max_depth=3,
    learning_rate=0.1,
    n_estimators=100,
    subsample_for_bin=200000,
    objective=None,
    class_weight=None,
    min_split_gain=0.0,
    min_child_weight=0.001,
    min_child_samples=20,
    subsample=1.0,
    subsample_freq=0,
    colsample_bytree=1.0,
    reg_alpha=0.0,
    reg_lambda=0.0,
    random_state=None,
    n_jobs=-1,
    silent=True,
    importance_type='split',
)

# %%
gbm.fit(X_train, y_train,
        eval_set=[(X_test, y_test)],
        eval_metric='l1',
        early_stopping_rounds=5)
# Out:
# [1]	valid_0's l1: 0.37542	valid_0's binary_logloss: 0.527219
# Training until validation scores don't improve for 5 rounds
# [2]	valid_0's l1: 0.351414	valid_0's binary_logloss: 0.480431
# [3]	valid_0's l1: 0.330004	valid_0's binary_logloss: 0.443091
# [4]	valid_0's l1: 0.311113	valid_0's binary_logloss: 0.412376
# [5]	valid_0's l1: 0.294077	valid_0's binary_logloss: 0.386658
# [6]	valid_0's l1: 0.278533	valid_0's binary_logloss: 0.364456
# [7]	valid_0's l1: 0.264136	valid_0's binary_logloss: 0.344697
# [8]	valid_0's l1: 0.251552	valid_0's binary_logloss: 0.327951
# [9]	valid_0's l1: 0.239489	valid_0's binary_logloss: 0.31245
# [10]	valid_0's l1: 0.22899	valid_0's binary_logloss: 0.299453
# [11]	valid_0's l1: 0.219207	valid_0's binary_logloss: 0.287826
# [12]	valid_0's l1: 0.21061	valid_0's binary_logloss: 0.277769
# [13]	valid_0's l1: 0.202462	valid_0's binary_logloss: 0.268717
# [14]	valid_0's l1: 0.19503	valid_0's binary_logloss: 0.260538
# [15]	valid_0's l1: 0.188435	valid_0's binary_logloss: 0.253188
# [16]	valid_0's l1: 0.182163	valid_0's binary_logloss: 0.24639
# [17]	valid_0's l1: 0.176692	valid_0's binary_logloss: 0.240532
# [18]	valid_0's l1: 0.171618	valid_0's binary_logloss: 0.235299
# [19]	valid_0's l1: 0.166831	valid_0's binary_logloss: 0.230267
# [20]	valid_0's l1: 0.162658	valid_0's binary_logloss: 0.225932
# [21]	valid_0's l1: 0.158761	valid_0's binary_logloss: 0.22217
# [22]	valid_0's l1: 0.155482	valid_0's binary_logloss: 0.218549
# [23]	valid_0's l1: 0.152192	valid_0's binary_logloss: 0.215233
# [24]	valid_0's l1: 0.149084	valid_0's binary_logloss: 0.211979
# [25]	valid_0's l1: 0.146368	valid_0's binary_logloss: 0.208926
# [26]	valid_0's l1: 0.143763	valid_0's binary_logloss: 0.206402
# [27]	valid_0's l1: 0.141064	valid_0's binary_logloss: 0.203059
# [28]	valid_0's l1: 0.13859	valid_0's binary_logloss: 0.199832
# [29]	valid_0's l1: 0.136443	valid_0's binary_logloss: 0.197846
# [30]	valid_0's l1: 0.134186	valid_0's binary_logloss: 0.195059
# [31]	valid_0's l1: 0.132149	valid_0's binary_logloss: 0.19228
# [32]	valid_0's l1: 0.130639	valid_0's binary_logloss: 0.190742
# [33]	valid_0's l1: 0.128689	valid_0's binary_logloss: 0.188
# [34]	valid_0's l1: 0.127036	valid_0's binary_logloss: 0.185795
# [35]	valid_0's l1: 0.125718	valid_0's binary_logloss: 0.18396
# [36]	valid_0's l1: 0.124214	valid_0's binary_logloss: 0.182051
# [37]	valid_0's l1: 0.122798	valid_0's binary_logloss: 0.180599
# [38]	valid_0's l1: 0.121538	valid_0's binary_logloss: 0.179365
# [39]	valid_0's l1: 0.120456	valid_0's binary_logloss: 0.177754
# [40]	valid_0's l1: 0.119103	valid_0's binary_logloss: 0.175985
# [41]	valid_0's l1: 0.118121	valid_0's binary_logloss: 0.17496
# [42]	valid_0's l1: 0.116916	valid_0's binary_logloss: 0.173453
# [43]	valid_0's l1: 0.115968	valid_0's binary_logloss: 0.172259
# [44]	valid_0's l1: 0.115284	valid_0's binary_logloss: 0.171487
# [45]	valid_0's l1: 0.114434	valid_0's binary_logloss: 0.170456
# [46]	valid_0's l1: 0.113409	valid_0's binary_logloss: 0.169267
# [47]	valid_0's l1: 0.112602	valid_0's binary_logloss: 0.168584
# [48]	valid_0's l1: 0.111851	valid_0's binary_logloss: 0.167525
# [49]	valid_0's l1: 0.110966	valid_0's binary_logloss: 0.166209
# [50]	valid_0's l1: 0.110324	valid_0's binary_logloss: 0.165492
# [51]	valid_0's l1: 0.109559	valid_0's binary_logloss: 0.164362
# [52]	valid_0's l1: 0.108936	valid_0's binary_logloss: 0.163486
# [53]	valid_0's l1: 0.108183	valid_0's binary_logloss: 0.162435
# [54]	valid_0's l1: 0.107614	valid_0's binary_logloss: 0.161574
# [55]	valid_0's l1: 0.107061	valid_0's binary_logloss: 0.160958
# [56]	valid_0's l1: 0.106648	valid_0's binary_logloss: 0.160447
# [57]	valid_0's l1: 0.105919	valid_0's binary_logloss: 0.159537
# [58]	valid_0's l1: 0.105398	valid_0's binary_logloss: 0.158776
# [59]	valid_0's l1: 0.104912	valid_0's binary_logloss: 0.158325
# [60]	valid_0's l1: 0.104508	valid_0's binary_logloss: 0.157967
# [61]	valid_0's l1: 0.104001	valid_0's binary_logloss: 0.157269
# [62]	valid_0's l1: 0.103441	valid_0's binary_logloss: 0.156698
# [63]	valid_0's l1: 0.103051	valid_0's binary_logloss: 0.156122
# [64]	valid_0's l1: 0.10259	valid_0's binary_logloss: 0.15568
# [65]	valid_0's l1: 0.102285	valid_0's binary_logloss: 0.15534
# [66]	valid_0's l1: 0.101876	valid_0's binary_logloss: 0.154755
# [67]	valid_0's l1: 0.101657	valid_0's binary_logloss: 0.154314
# [68]	valid_0's l1: 0.101141	valid_0's binary_logloss: 0.153739
# [69]	valid_0's l1: 0.100807	valid_0's binary_logloss: 0.153299
# [70]	valid_0's l1: 0.100232	valid_0's binary_logloss: 0.152595
# [71]	valid_0's l1: 0.0998414	valid_0's binary_logloss: 0.152132
# [72]	valid_0's l1: 0.0994147	valid_0's binary_logloss: 0.151732
# [73]	valid_0's l1: 0.0992258	valid_0's binary_logloss: 0.151587
# [74]	valid_0's l1: 0.0988875	valid_0's binary_logloss: 0.151237
# [75]	valid_0's l1: 0.0985266	valid_0's binary_logloss: 0.150853
# [76]	valid_0's l1: 0.0980556	valid_0's binary_logloss: 0.150196
# [77]	valid_0's l1: 0.0978744	valid_0's binary_logloss: 0.150061
# [78]	valid_0's l1: 0.097552	valid_0's binary_logloss: 0.149655
# [79]	valid_0's l1: 0.097316	valid_0's binary_logloss: 0.149393
# [80]	valid_0's l1: 0.0969744	valid_0's binary_logloss: 0.148943
# [81]	valid_0's l1: 0.0968452	valid_0's binary_logloss: 0.148555
# [82]	valid_0's l1: 0.0964943	valid_0's binary_logloss: 0.148092
# [83]	valid_0's l1: 0.0963121	valid_0's binary_logloss: 0.147922
# [84]	valid_0's l1: 0.096177	valid_0's binary_logloss: 0.147583
# [85]	valid_0's l1: 0.0958248	valid_0's binary_logloss: 0.147137
# [86]	valid_0's l1: 0.0954674	valid_0's binary_logloss: 0.146873
# [87]	valid_0's l1: 0.0952875	valid_0's binary_logloss: 0.146569
# [88]	valid_0's l1: 0.0950485	valid_0's binary_logloss: 0.146334
# [89]	valid_0's l1: 0.0946261	valid_0's binary_logloss: 0.145796
# [90]	valid_0's l1: 0.0944459	valid_0's binary_logloss: 0.145528
# [91]	valid_0's l1: 0.0943426	valid_0's binary_logloss: 0.145423
# [92]	valid_0's l1: 0.094234	valid_0's binary_logloss: 0.145108
# [93]	valid_0's l1: 0.0940298	valid_0's binary_logloss: 0.144891
# [94]	valid_0's l1: 0.0937558	valid_0's binary_logloss: 0.144592
# [95]	valid_0's l1: 0.0935165	valid_0's binary_logloss: 0.144333
# [96]	valid_0's l1: 0.0933674	valid_0's binary_logloss: 0.144213
# [97]	valid_0's l1: 0.0930441	valid_0's binary_logloss: 0.143804
# [98]	valid_0's l1: 0.0927724	valid_0's binary_logloss: 0.143483
# [99]	valid_0's l1: 0.0926173	valid_0's binary_logloss: 0.143298
# [100]	valid_0's l1: 0.0923771	valid_0's binary_logloss: 0.143143
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's l1: 0.0923771	valid_0's binary_logloss: 0.143143
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=3,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %% [markdown]
# # Performance analysis
# * roc_auc is 0.977
# * use "grid search" to find the optimization threshhold
# * the best threshold is 0.53

# %%
X_eva = raw_data[-EVA_SIZE:]
y_eva=new_match_list[-EVA_SIZE:]
X_eva = X_eva.astype(float)

# %%
from sklearn.metrics import precision_score,f1_score

# %%
result_prb = gbm.predict_proba(X_eva)
predict_classes = gbm.predict(X_eva)

# %%
precision_score(new_match_list[-EVA_SIZE:],predict_classes)
# Out:
# 0.9518918918918919

# %%
f1_score(new_match_list[-EVA_SIZE:],predict_classes)
# Out:
# 0.9620322316307021

# %%
## confusion mattix
from sklearn.metrics import confusion_matrix

tn, fp, fn, tp = confusion_matrix(new_match_list[-EVA_SIZE:],predict_classes).ravel()

# %%
(tn, fp, fn, tp)
# Out:
# (600, 89, 50, 1761)

# %% [markdown]
# ## ROC_AUC score is a good metric to measure the peformance

# %%
from sklearn.metrics import roc_auc_score

# %%
roc_auc_score(new_match_list[-EVA_SIZE:], result_prb[:,1])
# Out:
# 0.9847561146645358

# %%
gbm.feature_importances_
# Out:
# array([ 38,  74,  43,  93,  33,   1,  13,   1,  24,  11,   0,   0,  24,
#         10,   8,  33,  11,   1,   6,   6,  74,  38,  36,   3, 100,  18],
#       dtype=int32)

# %% [markdown]
# # Show Graph

# %%
print('Plotting 54th tree with graphviz...')
graph = lgb.create_tree_digraph(gbm, tree_index=53, name='Tree54')
graph.render(view=True)
# Out:
# Plotting 54th tree with graphviz...
# 'Tree54.gv.pdf'

# %%
graph

# %% [markdown]
# # DO testing

# %%
test_df = pd.read_csv("./address_matching_test.csv")
test_df.describe()
# Out:
#        name_levenshtein_simple  name_trigram_simple  name_levenshtein_term  \
# count              6230.000000          6230.000000            6230.000000
# mean                  0.617670             0.550384               0.521490
# std                   0.309591             0.372656               0.329626
# min                   0.000000             0.000000               0.000000
# 25%                   0.342857             0.172577               0.225806
# 50%                   0.666667             0.591837               0.448276
# 75%                   1.000000             1.000000               0.865116
# max                   1.000000             1.000000               1.000000
#
#        name_trigram_term
# count        6230.000000
# mean            0.493838
# std             0.375572
# min             0.000000
# 25%             0.120000
# 50%             0.450806
# 75%             1.000000
# max             1.000000

# %%
# miss value rate
for c in test_df.columns:
    print(c,str(sum(test_df[c]=='?')/6230)[:4])
# Out:
# id 0.0
# name_levenshtein_simple 0.0
# name_trigram_simple 0.0
# name_levenshtein_term 0.0
# name_trigram_term 0.0
# city_levenshtein_simple 0.64
# city_trigram_simple 0.64
# city_levenshtein_term 0.64
# city_trigram_term 0.64
# zip_levenshtein_simple 0.73
# zip_trigram_simple 0.73
# zip_levenshtein_term 0.73
# zip_trigram_term 0.73
# street_levenshtein_simple 0.71
# street_trigram_simple 0.71
# street_levenshtein_term 0.71
# street_trigram_term 0.71
# website_levenshtein_simple 0.94
# website_trigram_simple 0.94
# website_levenshtein_term 0.94
# website_trigram_term 0.94
# phone_levenshtein 0.59
# phone_trigram 0.59
# fax_levenshtein 0.97
# fax_trigram 0.97
# street_number_levenshtein 0.34
# street_number_trigram 0.34
# phone_equality 0.0
# fax_equality 0.0
# street_number_equality 0.0
# /usr/local/lib/python3.7/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
for c in test_df.columns:
    if 'equality' in c : 
        print("del",c)
        del test_df[c]
# Out:
# del phone_equality
# del fax_equality
# del street_number_equality

# %%
new_test_df = test_df.replace("?",-1)
for c in new_test_df.columns:
    print(c,str(sum(new_test_df[c]=='?')/6230)[:4])
# Out:
# id 0.0
# name_levenshtein_simple 0.0
# name_trigram_simple 0.0
# name_levenshtein_term 0.0
# name_trigram_term 0.0
# city_levenshtein_simple 0.0
# city_trigram_simple 0.0
# city_levenshtein_term 0.0
# city_trigram_term 0.0
# zip_levenshtein_simple 0.0
# zip_trigram_simple 0.0
# zip_levenshtein_term 0.0
# zip_trigram_term 0.0
# street_levenshtein_simple 0.0
# street_trigram_simple 0.0
# street_levenshtein_term 0.0
# street_trigram_term 0.0
# website_levenshtein_simple 0.0
# website_trigram_simple 0.0
# website_levenshtein_term 0.0
# website_trigram_term 0.0
# phone_levenshtein 0.0
# phone_trigram 0.0
# fax_levenshtein 0.0
# fax_trigram 0.0
# street_number_levenshtein 0.0
# street_number_trigram 0.0

# %%
# keep id list and remove it from test_df
id_test_list = new_test_df['id'].tolist()
del new_test_df['id']

# %%
raw_test_data = new_test_df
X_test = raw_test_data.astype(float)

# %%
# use model to predict the testing data
test_result = gbm.predict(X_test)

# %%
resut_df =  pd.DataFrame(test_result)

# %%
resut_df.describe()
# Out:
#                  0
# count  6230.000000
# mean      0.705136
# std       0.456018
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %%
best_th = 0.7

# %%
# testing data , predict result is as below
answer = list( zip(id_test_list,(test_result>best_th).astype(int).tolist()))

# %%
pd.DataFrame(answer).describe()
# Out:
#                  1
# count  6230.000000
# mean      0.705136
# std       0.456018
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %% [markdown]
# # Potential improvements
# * ensemble methodology
# * becasue fale positive rate is also import to operater. so in real case and production env , we need to build a doubel check mechanism
# * strong rule, such as decision tree . this algorithm could produce the human readable result and rule that help our user to understnad the system behavior.

# %% [markdown]
# # Conclusion
# * this is a very good challenge to test a data scientist.
# * i just build only one model , but i think is so far so good as baseline model.
